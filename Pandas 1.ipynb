# %%
tips = sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
tips_gb = tips.groupby(['day','sex']).agg({'size':'sum'})
tips_gb
# Out:
#              size
# day  sex
# Thur Male      73
#      Female    79
# Fri  Male      21
#      Female    19
# Sat  Male     156
#      Female    63
# Sun  Male     163
#      Female    53

# %%
tips_us = tips_gb.unstack()
tips_us
# Out:
#      size
# sex  Male Female
# day
# Thur   73     79
# Fri    21     19
# Sat   156     63
# Sun   163     53

# %%
tips_gb.unstack(0)
# Out:
#        size
# day    Thur Fri  Sat  Sun
# sex
# Male     73  21  156  163
# Female   79  19   63   53

# %%
tips_us.columns
# Out:
# MultiIndex([('size',   'Male'),
#             ('size', 'Female')],
#            names=[None, 'sex'])

# %%
tips_us[[('size','Male')]]
# Out:
#      size
# sex  Male
# day
# Thur   73
# Fri    21
# Sat   156
# Sun   163

# %%
tips_us_copy = tips_us.copy()
tips_us_copy
# Out:
#      size
# sex  Male Female
# day
# Thur   73     79
# Fri    21     19
# Sat   156     63
# Sun   163     53

# %%
tips_us_copy = tips_us.copy()
tips_us_copy.columns = ['___'.join(col).strip() for col in tips_us.columns.values]

# %%
tips_us_copy
# Out:
#       size___Male  size___Female
# day
# Thur           73             79
# Fri            21             19
# Sat           156             63
# Sun           163             53

# %%
tips_us_copy.size___Male/tips_us_copy.size___Female
# Out:
# day
# Thur    0.924051
# Fri     1.105263
# Sat     2.476190
# Sun     3.075472
# dtype: float64

# %%
tips_us
# Out:
#      size
# sex  Male Female
# day
# Thur   73     79
# Fri    21     19
# Sat   156     63
# Sun   163     53

# %%
tips_us.stack()
# Out:
#              size
# day  sex
# Thur Male      73
#      Female    79
# Fri  Male      21
#      Female    19
# Sat  Male     156
#      Female    63
# Sun  Male     163
#      Female    53

# %%
tips_us.stack(0)
# Out:
# sex        Male  Female
# day
# Thur size    73      79
# Fri  size    21      19
# Sat  size   156      63
# Sun  size   163      53

# %%
is_weekend = tips.day.isin(["Sat","Sun"]).sample(5)
is_weekend
# Out:
# 113    True
# 150    True
# 109    True
# 211    True
# 69     True
# Name: day, dtype: bool

# %%
tips[["time","day"]].drop_duplicates(keep="first")
# Out:
#        time   day
# 0    Dinner   Sun
# 19   Dinner   Sat
# 77    Lunch  Thur
# 90   Dinner   Fri
# 220   Lunch   Fri
# 243  Dinner  Thur

# %%
pd.cut(tips["total_bill"],3, labels=['low','mid','high']).head()
# Out:
# 0    low
# 1    low
# 2    mid
# 3    mid
# 4    mid
# Name: total_bill, dtype: category
# Categories (3, object): ['low' < 'mid' < 'high']

# %%
tips.sex.str.lower().head()
# Out:
# 0    female
# 1      male
# 2      male
# 3      male
# 4    female
# Name: sex, dtype: object

# %%
s=tips.sex.str

# %%
s.replace
# Out:
# <bound method StringMethods.replace of <pandas.core.strings.accessor.StringMethods object at 0x000002A97970A9E8>>

# %%
tips["tip"]
# Out:
# 0      1.01
# 1      1.66
# 2      3.50
# 3      3.31
# 4      3.61
#        ...
# 239    5.92
# 240    2.00
# 241    2.00
# 242    1.75
# 243    3.00
# Name: tip, Length: 244, dtype: float64

# %%
tips.loc[2:3,"sex":'smoker']
# Out:
#     sex smoker
# 2  Male     No
# 3  Male     No

# %%
mi_tips = tips.groupby(['sex','smoker']).agg({'tip':'mean'})
mi_tips
# Out:
#                     tip
# sex    smoker
# Male   Yes     3.051167
#        No      3.113402
# Female Yes     2.931515
#        No      2.773519

# %%
mi_tips = tips.groupby(['sex','smoker']).agg({'tip':'sum'})
mi_tips
# Out:
#                   tip
# sex    smoker
# Male   Yes     183.07
#        No      302.00
# Female Yes      96.74
#        No      149.77

# %%
ri_tips = mi_tips.reset_index()
ri_tips
# Out:
#       sex smoker     tip
# 0    Male    Yes  183.07
# 1    Male     No  302.00
# 2  Female    Yes   96.74
# 3  Female     No  149.77

# %%
ri_tips[(ri_tips['smoker']=="No") & (ri_tips['sex'] == 'Male')]
# Out:
#     sex smoker    tip
# 1  Male     No  302.0

# %%
mi_tips.reset_index(level=0)
# Out:
#            sex     tip
# smoker
# Yes       Male  183.07
# No        Male  302.00
# Yes     Female   96.74
# No      Female  149.77

# %%
rio_tips = mi_tips.reset_index(level=0)
rio_tips.loc['Yes']
# Out:
#            sex     tip
# smoker
# Yes       Male  183.07
# Yes     Female   96.74

# %%
ri_tips
# Out:
#       sex smoker     tip
# 0    Male    Yes  183.07
# 1    Male     No  302.00
# 2  Female    Yes   96.74
# 3  Female     No  149.77

# %%
ri_tips.set_index(["sex","smoker"])
# Out:
#                   tip
# sex    smoker
# Male   Yes     183.07
#        No      302.00
# Female Yes      96.74
#        No      149.77

# %%
rio_tips.set_index('sex',append =True)
# Out:
#                   tip
# smoker sex
# Yes    Male    183.07
# No     Male    302.00
# Yes    Female   96.74
# No     Female  149.77

# %%
tips.at[0, 'total_bill']=6
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0        6.00  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.at[1:4, 'total_bill']=900
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0          6.00  1.01  Female     No   Sun  Dinner     2
# 1        900.00  1.66    Male     No   Sun  Dinner     3
# 2        900.00  3.50    Male     No   Sun  Dinner     3
# 3        900.00  3.31    Male     No   Sun  Dinner     2
# 4        900.00  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.iat[0,4]
# Out:
# 'Sun'

# %%
df = pd.DataFrame(np.random.randn(25).reshape((5,5)))
df.head()
# Out:
#           0         1         2         3         4
# 0  0.420936 -0.449742 -0.547941 -0.134668 -0.678033
# 1 -1.067060 -2.050491  0.562014  0.503676 -1.436014
# 2  1.116349 -0.762917 -0.849710  0.786314 -1.098807
# 3  0.011300  1.284916  1.369822  0.202433  0.843549
# 4  0.522151  0.491231 -0.604218 -0.018695  1.435459

# %%
df.where(df>0)
# Out:
#           0         1         2         3         4
# 0  0.420936       NaN       NaN       NaN       NaN
# 1       NaN       NaN  0.562014  0.503676       NaN
# 2  1.116349       NaN       NaN  0.786314       NaN
# 3  0.011300  1.284916  1.369822  0.202433  0.843549
# 4  0.522151  0.491231       NaN       NaN  1.435459

# %%
df[df<0] = np.NaN
df
# Out:
#           0         1         2         3         4
# 0  0.420936       NaN       NaN       NaN       NaN
# 1       NaN       NaN  0.562014  0.503676       NaN
# 2  1.116349       NaN       NaN  0.786314       NaN
# 3  0.011300  1.284916  1.369822  0.202433  0.843549
# 4  0.522151  0.491231       NaN       NaN  1.435459

# %%
df = pd.read_csv('fav_foods.csv')
df
# Out:
#     id                       email                           favorite_foods
# 0    1     liberty.hayes@email.com  apple pie, hot dog, macaroni and cheese
# 1    2    mallory.spears@email.com              sushi, fried chicken, pizza
# 2    3       easton.lara@email.com         enchiladas, apple pie, hamburger
# 3    4    jaslyn.mathews@email.com                steak, hamburger, hot dog
# 4    5   juliet.erickson@email.com                        poutine, sandwich
# 5    6   laylah.sullivan@email.com      french fries, ramen, fish and chips
# 6    7  kenzie.underwood@email.com               sushi, curly fries, chilps
# 7    8    alexandra.raig@email.com                                      NaN
# 8    9   solomon.rollins@email.com                         hot dog, poutine
# 9   10    alisha.mcgrath@email.com                         ramen, spaghetti
# 10  11    jakayla.suarez@email.com                lasagna, sushi, hamburger
# ...

# %%
df.rename(columns={"email":"Email"}, inplace=True)
df
# Out:
#     id                       Email                           favorite_foods
# 0    1     liberty.hayes@email.com  apple pie, hot dog, macaroni and cheese
# 1    2    mallory.spears@email.com              sushi, fried chicken, pizza
# 2    3       easton.lara@email.com         enchiladas, apple pie, hamburger
# 3    4    jaslyn.mathews@email.com                steak, hamburger, hot dog
# 4    5   juliet.erickson@email.com                        poutine, sandwich
# 5    6   laylah.sullivan@email.com      french fries, ramen, fish and chips
# 6    7  kenzie.underwood@email.com               sushi, curly fries, chilps
# 7    8    alexandra.raig@email.com                                      NaN
# 8    9   solomon.rollins@email.com                         hot dog, poutine
# 9   10    alisha.mcgrath@email.com                         ramen, spaghetti
# 10  11    jakayla.suarez@email.com                lasagna, sushi, hamburger
# ...

# %%
df['Email'].str.split('.')
# Out:
# 0        [liberty, hayes@email, com]
# 1       [mallory, spears@email, com]
# 2          [easton, lara@email, com]
# 3       [jaslyn, mathews@email, com]
# 4      [juliet, erickson@email, com]
# 5      [laylah, sullivan@email, com]
# 6     [kenzie, underwood@email, com]
# 7       [alexandra, raig@email, com]
# 8      [solomon, rollins@email, com]
# 9       [alisha, mcgrath@email, com]
# 10      [jakayla, suarez@email, com]
# 11       [alvaro, mccann@email, com]
# 12     [derrick, jackson@email, com]
# 13           [gina, ball@email, com]
# 14       [myles, hendrix@email, com]
# Name: Email, dtype: object

# %%
df['Email'].str.split('.',n=1)
# Out:
# 0        [liberty, hayes@email.com]
# 1       [mallory, spears@email.com]
# 2          [easton, lara@email.com]
# 3       [jaslyn, mathews@email.com]
# 4      [juliet, erickson@email.com]
# 5      [laylah, sullivan@email.com]
# 6     [kenzie, underwood@email.com]
# 7       [alexandra, raig@email.com]
# 8      [solomon, rollins@email.com]
# 9       [alisha, mcgrath@email.com]
# 10      [jakayla, suarez@email.com]
# 11       [alvaro, mccann@email.com]
# 12     [derrick, jackson@email.com]
# 13           [gina, ball@email.com]
# 14       [myles, hendrix@email.com]
# Name: Email, dtype: object

# %%
split_email = df["Email"].str.split('.',n=1,expand=True)
split_email
# Out:
#             0                    1
# 0     liberty      hayes@email.com
# 1     mallory     spears@email.com
# 2      easton       lara@email.com
# 3      jaslyn    mathews@email.com
# 4      juliet   erickson@email.com
# 5      laylah   sullivan@email.com
# 6      kenzie  underwood@email.com
# 7   alexandra       raig@email.com
# 8     solomon    rollins@email.com
# 9      alisha    mcgrath@email.com
# 10    jakayla     suarez@email.com
# 11     alvaro     mccann@email.com
# 12    derrick    jackson@email.com
# 13       gina       ball@email.com
# 14      myles    hendrix@email.com

# %%
split_email.rename(columns={0:"first_name",1:"last_.com"},inplace=True)
split_email
# Out:
#    first_name            last_.com
# 0     liberty      hayes@email.com
# 1     mallory     spears@email.com
# 2      easton       lara@email.com
# 3      jaslyn    mathews@email.com
# 4      juliet   erickson@email.com
# 5      laylah   sullivan@email.com
# 6      kenzie  underwood@email.com
# 7   alexandra       raig@email.com
# 8     solomon    rollins@email.com
# 9      alisha    mcgrath@email.com
# 10    jakayla     suarez@email.com
# 11     alvaro     mccann@email.com
# 12    derrick    jackson@email.com
# 13       gina       ball@email.com
# 14      myles    hendrix@email.com

# %%
split_email2 = df['Email'].str.split('.', n=1, expand=True).rename(columns={0:"first_name", 1:"last_.com"})
split_email2
# Out:
#    first_name            last_.com
# 0     liberty      hayes@email.com
# 1     mallory     spears@email.com
# 2      easton       lara@email.com
# 3      jaslyn    mathews@email.com
# 4      juliet   erickson@email.com
# 5      laylah   sullivan@email.com
# 6      kenzie  underwood@email.com
# 7   alexandra       raig@email.com
# 8     solomon    rollins@email.com
# 9      alisha    mcgrath@email.com
# 10    jakayla     suarez@email.com
# 11     alvaro     mccann@email.com
# 12    derrick    jackson@email.com
# 13       gina       ball@email.com
# 14      myles    hendrix@email.com

# %%
df[['first_name','last_name']] = df['Email'].str.split('.', n=1, expand=True)
df
# Out:
#     id                       Email                           favorite_foods  \
# 0    1     liberty.hayes@email.com  apple pie, hot dog, macaroni and cheese
# 1    2    mallory.spears@email.com              sushi, fried chicken, pizza
# 2    3       easton.lara@email.com         enchiladas, apple pie, hamburger
# 3    4    jaslyn.mathews@email.com                steak, hamburger, hot dog
# 4    5   juliet.erickson@email.com                        poutine, sandwich
# 5    6   laylah.sullivan@email.com      french fries, ramen, fish and chips
# 6    7  kenzie.underwood@email.com               sushi, curly fries, chilps
# 7    8    alexandra.raig@email.com                                      NaN
# 8    9   solomon.rollins@email.com                         hot dog, poutine
# 9   10    alisha.mcgrath@email.com                         ramen, spaghetti
# 10  11    jakayla.suarez@email.com                lasagna, sushi, hamburger
# ...

# %%
df['last_name'] = df['last_name'].str.replace('@email.com','',regex=True)
df.sample(5)
# Out:
#     id                      Email                       favorite_foods  \
# 5    6  laylah.sullivan@email.com  french fries, ramen, fish and chips
# 1    2   mallory.spears@email.com          sushi, fried chicken, pizza
# 11  12    alvaro.mccann@email.com         pizza, enchiladas, apple pie
# 3    4   jaslyn.mathews@email.com            steak, hamburger, hot dog
# 13  14        gina.ball@email.com               rice, poutine, hot dog
#
#    first_name last_name
# 5      laylah  sullivan
# 1     mallory    spears
# 11     alvaro    mccann
# 3      jaslyn   mathews
# 13       gina      ball

# %%
df[['fav1','fav2','fav3']] = df['favorite_foods'].str.split(', ', expand=True)
df
# Out:
#     id                       Email                           favorite_foods  \
# 0    1     liberty.hayes@email.com  apple pie, hot dog, macaroni and cheese
# 1    2    mallory.spears@email.com              sushi, fried chicken, pizza
# 2    3       easton.lara@email.com         enchiladas, apple pie, hamburger
# 3    4    jaslyn.mathews@email.com                steak, hamburger, hot dog
# 4    5   juliet.erickson@email.com                        poutine, sandwich
# 5    6   laylah.sullivan@email.com      french fries, ramen, fish and chips
# 6    7  kenzie.underwood@email.com               sushi, curly fries, chilps
# 7    8    alexandra.raig@email.com                                      NaN
# 8    9   solomon.rollins@email.com                         hot dog, poutine
# 9   10    alisha.mcgrath@email.com                         ramen, spaghetti
# 10  11    jakayla.suarez@email.com                lasagna, sushi, hamburger
# ...

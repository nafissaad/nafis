# %%
from statsmodels.tsa.stattools import grangercausalitytests
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
t1 = [0.1*np.random.normal()]
for _ in range(100):
    t1.append(0.5*t1[-1] + 0.1*np.random.normal())

# %%
t2 = [item + 0.1*np.random.normal() for item in t1]

# %%
t1 = t1[3:]
t2 = t2[:-3]

# %%
plt.figure(figsize=(10,4))
plt.plot(t1, color='b')
plt.plot(t2, color='r')

plt.legend(['t1', 't2'], fontsize=16)

# %%
ts_df = pd.DataFrame(columns=['t2', 't1'], data=zip(t2,t1))

# %%
ts_df
# Out:
#           t2        t1
# 0  -0.241488 -0.047039
# 1  -0.019457 -0.060929
# 2  -0.153942 -0.098063
# 3  -0.093479  0.019451
# 4  -0.019772  0.069167
# ..       ...       ...
# 93 -0.226152 -0.165251
# 94  0.084631 -0.092907
# 95  0.157333 -0.173760
# 96 -0.140177  0.175833
# 97 -0.279894  0.307231
#
# [98 rows x 2 columns]

# %%
gc_res = grangercausalitytests(ts_df, 3)
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.7993  , p=0.3736  , df_denom=94, df_num=1
# ssr based chi2 test:   chi2=0.8248  , p=0.3638  , df=1
# likelihood ratio test: chi2=0.8213  , p=0.3648  , df=1
# parameter F test:         F=0.7993  , p=0.3736  , df_denom=94, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=2.3040  , p=0.1057  , df_denom=91, df_num=2
# ssr based chi2 test:   chi2=4.8613  , p=0.0880  , df=2
# likelihood ratio test: chi2=4.7422  , p=0.0934  , df=2
# parameter F test:         F=2.3040  , p=0.1057  , df_denom=91, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=25.8144 , p=0.0000  , df_denom=88, df_num=3
# ssr based chi2 test:   chi2=83.6033 , p=0.0000  , df=3
# likelihood ratio test: chi2=59.9726 , p=0.0000  , df=3
# parameter F test:         F=25.8144 , p=0.0000  , df_denom=88, df_num=3

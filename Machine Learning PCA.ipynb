# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('heart(pca).csv')
df
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
df.shape
# Out:
# (918, 12)

# %%
df.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean    53.510893  132.396514   198.799564    0.233115  136.809368
# std      9.432617   18.514154   109.384145    0.423046   25.460334
# min     28.000000    0.000000     0.000000    0.000000   60.000000
# 25%     47.000000  120.000000   173.250000    0.000000  120.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease
# count  918.000000    918.000000
# mean     0.887364      0.553377
# std      1.066570      0.497414
# min     -2.600000      0.000000
# 25%      0.000000      0.000000
# 50%      0.600000      1.000000
# 75%      1.500000      1.000000
# max      6.200000      1.000000

# %%
plt.boxplot(df['Cholesterol'])
plt.show()

# %%
df['Cholesterol'].max(),df['Cholesterol'].min(),df['Cholesterol'].mean(),df['Cholesterol'].mode()
# Out:
# (603,
#  0,
#  198.7995642701525,
#  0    0
#  dtype: int64)

# %%
df[df.Cholesterol>(df.Cholesterol.mean()+2*df.Cholesterol.std())]
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 28    53   F           ATA        113          468          0     Normal
# 30    53   M           NAP        145          518          0     Normal
# 76    32   M           ASY        118          529          0     Normal
# 103   40   M           ASY        120          466          1     Normal
# 149   54   M           ASY        130          603          1     Normal
# 250   44   M           ASY        135          491          0     Normal
# 496   58   M           ASY        132          458          1     Normal
# 616   67   F           NAP        115          564          0        LVH
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 28     127              N      0.0       Up             0
# 30     130              N      0.0     Flat             1
# 76     130              N      0.0     Flat             1
# 103    152              Y      1.0     Flat             1
# ...

# %%
df1 = df[df.Cholesterol<=(df.Cholesterol.mean()+1*df.Cholesterol.std())]
df1.shape
# Out:
# (838, 12)

# %%
plt.boxplot(df1['Cholesterol'])
plt.show()

# %%
df1[df1.FastingBS>(df1.FastingBS.mean()+1*df.FastingBS.std())]
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 36    65   M           ASY        140          306          1     Normal
# 38    48   F           ATA        120          177          1         ST
# 52    45   M           ATA        140          224          1     Normal
# 84    56   M           ASY        150          213          1     Normal
# 86    65   M           ASY        170          263          1     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 887   43   M           ASY        132          247          1        LVH
# 888   52   M           ASY        128          204          1     Normal
# 901   58   F           ASY        170          225          1        LVH
# 911   59   M           ASY        164          176          1        LVH
# 914   68   M           ASY        144          193          1     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
df1[df1.Oldpeak>(df1.Oldpeak.mean()+1*df1.Oldpeak.std())]
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 11    58   M           ATA        136          164          0         ST
# 19    36   M           ATA        120          267          0     Normal
# 23    44   M           ATA        150          288          0     Normal
# 26    53   M           ASY        124          260          0         ST
# 32    54   M           ASY        125          224          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 897   55   F           ASY        128          205          0         ST
# 901   58   F           ASY        170          225          1        LVH
# 907   44   M           ASY        120          169          0     Normal
# 908   63   M           ASY        140          187          0        LVH
# 914   68   M           ASY        144          193          1     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
df2 = df1[df1.Oldpeak<=(df1.Oldpeak.mean()+1*df1.Oldpeak.std())]
df2.shape
# Out:
# (679, 12)

# %%
df2[df2.RestingBP>(df2.RestingBP.mean()+1*df2.RestingBP.std())]
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 1     49   F           NAP        160          180          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# 34    43   F           ATA        150          186          0     Normal
# 39    48   F           ASY        150          227          0     Normal
# 40    54   F           ATA        150          230          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 884   67   M           ASY        160          286          0        LVH
# 890   64   M            TA        170          227          0        LVH
# 893   57   M           ATA        154          232          0        LVH
# 905   67   M           NAP        152          212          0        LVH
# 911   59   M           ASY        164          176          1        LVH
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
df3 = df2[df2.RestingBP<=(df2.RestingBP.mean()+1*df2.RestingBP.std())]
df3.shape
# Out:
# (563, 12)

# %%
df.ChestPainType.unique()
# Out:
# array(['ATA', 'NAP', 'ASY', 'TA'], dtype=object)

# %%
df.RestingECG.unique()
# Out:
# array(['Normal', 'ST', 'LVH'], dtype=object)

# %%
df.ExerciseAngina.unique()
# Out:
# array(['N', 'Y'], dtype=object)

# %%
df.ST_Slope.unique()
# Out:
# array(['Up', 'Flat', 'Down'], dtype=object)

# %%
df4 = df3.copy()
df4.ExerciseAngina.replace(
    {
        'N': 0,
        'Y': 1
    },
    inplace=True)

df4.ST_Slope.replace(
    {
        'Down': 1,
        'Flat': 2,
        'Up': 3
    },
    inplace=True
)

df4.RestingECG.replace(
    {
        'Normal': 1,
        'ST': 2,
        'LVH': 3
    },
    inplace=True)

df4.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS  RestingECG  \
# 0   40   M           ATA        140          289          0           1
# 2   37   M           ATA        130          283          0           2
# 3   48   F           ASY        138          214          0           1
# 6   45   F           ATA        130          237          0           1
# 7   54   M           ATA        110          208          0           1
#
#    MaxHR  ExerciseAngina  Oldpeak  ST_Slope  HeartDisease
# 0    172               0      0.0         3             0
# 2     98               0      0.0         3             0
# 3    108               1      1.5         2             1
# 6    170               0      0.0         3             0
# 7    142               0      0.0         3             0

# %%
df5 = pd.get_dummies(df4, drop_first=True)
df5.head()
# Out:
#    Age  RestingBP  Cholesterol  FastingBS  RestingECG  MaxHR  ExerciseAngina  \
# 0   40        140          289          0           1    172               0
# 2   37        130          283          0           2     98               0
# 3   48        138          214          0           1    108               1
# 6   45        130          237          0           1    170               0
# 7   54        110          208          0           1    142               0
#
#    Oldpeak  ST_Slope  HeartDisease  Sex_M  ChestPainType_ATA  \
# 0      0.0         3             0      1                  1
# 2      0.0         3             0      1                  1
# 3      1.5         2             1      0                  0
# 6      0.0         3             0      0                  1
# 7      0.0         3             0      1                  1
#
#    ChestPainType_NAP  ChestPainType_TA
# 0                  0                 0
# 2                  0                 0
# ...

# %%
x = df5.drop("HeartDisease",axis='columns')
y = df5.HeartDisease

x.head()
# Out:
#    Age  RestingBP  Cholesterol  FastingBS  RestingECG  MaxHR  ExerciseAngina  \
# 0   40        140          289          0           1    172               0
# 2   37        130          283          0           2     98               0
# 3   48        138          214          0           1    108               1
# 6   45        130          237          0           1    170               0
# 7   54        110          208          0           1    142               0
#
#    Oldpeak  ST_Slope  Sex_M  ChestPainType_ATA  ChestPainType_NAP  \
# 0      0.0         3      1                  1                  0
# 2      0.0         3      1                  1                  0
# 3      1.5         2      0                  0                  0
# 6      0.0         3      0                  1                  0
# 7      0.0         3      1                  1                  0
#
#    ChestPainType_TA
# 0                 0
# 2                 0
# 3                 0
# ...

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(x)
X_scaled

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=30)

# %%
X_train.shape
# Out:
# (717, 13)

# %%
X_test.shape
# Out:
# (180, 13)

# %%
from sklearn.ensemble import RandomForestClassifier

model_rf = RandomForestClassifier()
model_rf.fit(X_train, y_train)
model_rf.score(X_test, y_test)
# Out:
# 0.9

# %%
from sklearn.decomposition import PCA

pca = PCA(0.95)
X_pca = pca.fit_transform(X)
X_pca
# Out:
# array([[ 95.52835133, -28.77535288],
#        [-13.89583819, -13.74667236],
#        [ 84.6609611 ,  39.02413578],
#        ...,
#        [-66.08441191,  17.46522553],
#        [ 42.42500339, -33.00244685],
#        [-18.17458001, -37.10701265]])

# %%
X_train_pca, X_test_pca, y_train, y_test = train_test_split(X_pca, y, test_size=0.2, random_state=30)

# %%
from sklearn.ensemble import RandomForestClassifier

model_rf = RandomForestClassifier()
model_rf.fit(X_train_pca, y_train)
model_rf.score(X_test_pca, y_test)
# Out:
# 0.7222222222222222
